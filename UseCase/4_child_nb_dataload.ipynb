# %%
import requests

# Define the URL of the data source
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"

# Perform the API call (GET request)
Url_Data = requests.get(url)

dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",Url_Data.text,overwrite=True)
